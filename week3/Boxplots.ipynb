# %% [markdown]
# <a href="https://colab.research.google.com/github/clementeaf/codingDojo-DS/blob/main/week3/Boxplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
filename = '/content/drive/My Drive/wisconsinBreastCancer.csv'
df = pd.read_csv(filename)
df.head()

# %%
malignant = df.loc[df['diagnosis']=='M','area_mean'].values
benign = df.loc[df['diagnosis']=='B','area_mean'].values
plt.boxplot([malignant,benign], labels=['M', 'B']);

# %%
# Getting rid of area_mean
df.boxplot(column = 'area_mean', by = 'diagnosis');

# %%
# Same plot but without the area_mean subtitle and title
df.boxplot(column = 'area_mean', by = 'diagnosis');
plt.title('');
plt.suptitle('');

# %%
sns.boxplot(x='diagnosis', y='area_mean', data=df)
# Out:
# <Axes: xlabel='diagnosis', ylabel='area_mean'>

# %%
malignant = df.loc[df['diagnosis']=='M','area_mean']
benign = df.loc[df['diagnosis']=='B','area_mean']
fig, axes = plt.subplots(nrows = 1, ncols = 1)
axes.boxplot([malignant,benign], notch = True, labels=['M', 'B']);

# %%
malignant = df.loc[df['diagnosis']=='M','area_mean']
benign = df.loc[df['diagnosis']=='B','area_mean']
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (8,5))
boxplots = axes.boxplot([malignant,benign],
           notch = True,
           labels=['M', 'B'],
           widths = .7,
           patch_artist=True,
           medianprops = dict(linestyle='-', linewidth=2, color='Yellow'),
           boxprops = dict(linestyle='--', linewidth=2, color='Black', facecolor = 'blue', alpha = .4)
          );
# The more you understand any library, the more you can do
boxplot1 = boxplots['boxes'][0]
boxplot1.set_facecolor('red')
plt.xlabel('diagnosis', fontsize = 20);
plt.ylabel('area_mean', fontsize = 20);
plt.xticks(fontsize = 16);
plt.yticks(fontsize = 16);
